# %%
import numpy as np
import pandas as pd
import pickle

# %%
movies = pd.read_csv('/content/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#director
def get_director(mydict):
  for i in eval(mydict):
    if i['job']=='Director':
      return i['name']

# %%
movies['director'] = movies.crew.apply(get_director)

# %%
movies['original_language'].value_counts()
# Out:
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
def convert_country_names(val,x):
      if val[x] == 'en':
          val[x] = 'English'
      elif val[x] == 'fr':
          val[x] = 'French'
      elif val[x] == 'es':
          val[x] = 'Spanish'
      elif val[x] == 'zh':
          val[x] = 'Chinese'
      elif val[x] == 'de':
          val[x] = 'German'
      elif val[x] == 'hi':
          val[x] = 'Hindi'
      elif val[x] == 'ja':
          val[x] = 'Japanese'
      elif val[x] == 'it':
          val[x] = 'Italian'
      elif val[x] == 'cn':
          val[x] = 'China'
      elif val[x] == 'ru':
          val[x] = 'Russian Federation'
      elif val[x] == 'ko':
          val[x] = 'Korean'
      elif val[x] == 'pt':
          val[x] = 'Portuguese'
      elif val[x] == 'da':
          val[x] = 'Danish'
      elif val[x] == 'sv':
          val[x] = 'Swedish'
      elif val[x] == 'nl':
          val[x] = 'Dutch'
      elif val[x] == 'fa':
          val[x] = 'Persian (Farsi)'
      elif val[x] == 'th':
          val[x] = 'Thai'
      elif val[x] == 'he':
          val[x] = 'Hebrew'
      elif val[x] == 'ta':
          val[x] = 'Tamil'
      elif val[x] == 'cs':
          val[x] = 'Czech'
      elif val[x] == 'ro':
          val[x] = 'Romanian'
      elif val[x] == 'id':
          val[x] = 'Indonesian'
      elif val[x] == 'ar':
          val[x] = 'Arabic'
      elif val[x] == 'vi':
          val[x] = 'Vietnamese'
      elif val[x] == 'sl':
          val[x] = 'Slovenian'
      elif val[x] == 'ps':
          val[x] = 'Pashto'
      elif val[x] == 'no':
          val[x] = 'Norwegian'
      elif val[x] == 'ky':
          val[x] = 'Kyrgyz'
      elif val[x] == 'hu':
          val[x] = 'Hungarian'
      elif val[x] == 'pl':
          val[x] = 'Polish'
      elif val[x] == 'af':
          val[x] = 'Afrikaans'
      elif val[x] == 'nb':
          val[x] = 'Norwegian Bokmål'
      elif val[x] == 'tr':
          val[x] = 'Turkish'
      elif val[x] =='is':
          val[x] ='Icelandic'
      elif val[x] =='xx':
          val[x] ='Unknown'
      elif val[x] =='te':
          val[x] ='Telugu'
      elif val[x] =='el':
          val[x] ='Greek'

# %%
for i in range(len(movies['original_language'])):
  convert_country_names(movies['original_language'],i)
# Out:
# <ipython-input-11-3340667cec77>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val[x] = 'English'
# <ipython-input-11-3340667cec77>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val[x] = 'Japanese'
# <ipython-input-11-3340667cec77>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val[x] = 'French'
# <ipython-input-11-3340667cec77>:9: SettingWithCopyWarning:
# ...

# %%
movies.original_language
# Out:
# 0       English
# 1       English
# 2       English
# 3       English
# 4       English
#          ...
# 4804    Spanish
# 4805    English
# 4806    English
# 4807    English
# 4808    English
# Name: original_language, Length: 4809, dtype: object

# %%
def production(my_dict):
  if len(eval(my_dict))==0:
    return ''
  return eval(my_dict)[0]['name']

# %%
movies['production_countries']=movies['production_countries'].apply(production)

# %%
movies['production_countries'].value_counts()
# Out:
# United States of America    3104
# United Kingdom               375
# Canada                       221
# Germany                      200
# France                       174
#                             ...
# Singapore                      1
# Peru                           1
# Malta                          1
# Philippines                    1
# Kenya                          1
# Name: production_countries, Length: 71, dtype: int64

# %%
def get_actor(mydict):
  if len(eval(mydict))==0:
    return ''
  return eval(mydict)[0]['name']

# %%
movies['main actor']=movies.cast.apply(get_actor)

# %%
def get_genres(my_dict):
  if len(eval(my_dict))==0:
    return ''
  return eval(my_dict)[0]['name']

# %%
movies['main genre']=movies['genres'].apply(get_genres)

# %%
movies['main genre'].value_counts()
# Out:
# Drama              1209
# Comedy             1042
# Action              755
# Adventure           339
# Horror              301
# Crime               195
# Thriller            194
# Animation           123
# Fantasy             118
# Romance             106
# Science Fiction      96
# Documentary          89
# Family               57
# Mystery              41
# Music                34
#                      28
# Western              27
# History              25
# War                  24
# TV Movie              4
# Foreign               2
# Name: main genre, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
#prediction
search=movies[['main actor','main genre','original_language','director','production_countries','title']]

# %%
search.head(3)
# Out:
#         main actor main genre original_language        director  \
# 0  Sam Worthington     Action           English   James Cameron
# 1      Johnny Depp  Adventure           English  Gore Verbinski
# 2     Daniel Craig     Action           English      Sam Mendes
#
#        production_countries                                     title
# 0  United States of America                                    Avatar
# 1  United States of America  Pirates of the Caribbean: At World's End
# 2            United Kingdom                                   Spectre

# %%
ac=input("Enter actor:")
# Out:
# Enter actor:Johnny Depp

# %%
gen=input("Enter genre:")
# Out:
# Enter genre:Adventure

# %%
ol=input("original_language:")
# Out:
# original_language:English

# %%
dir=input("Enter Director:")
# Out:
# Enter Director:Gore Verbinski

# %%
pc=input("Production_countries:")
# Out:
# Production_countries:United States of America

# %%
movie_find=search[(search['director']==dir) & (search['main actor']==ac) & (search['main genre']==gen) & (search['production_countries']==pc) & (search['original_language']==ol)]
movie_find
# Out:
#       main actor main genre original_language        director  \
# 1    Johnny Depp  Adventure           English  Gore Verbinski
# 199  Johnny Depp  Adventure           English  Gore Verbinski
#
#          production_countries  \
# 1    United States of America
# 199  United States of America
#
#                                                  title
# 1             Pirates of the Caribbean: At World's End
# 199  Pirates of the Caribbean: The Curse of the Bla...

# %%
#pickle file downloading
data={'model':search,'actor':search['main actor'],'genre':search['main genre'],'director':search['director'],'production':search['production_countries'],'language':search['original_language']}

# %%
with open('prediction.pkl','wb') as model:
  pickle.dump(data,model)

# %%
with open('prediction.pkl','rb') as model:
  data=pickle.load(model)
dataset=data['model']
actor=search['main actor']
director=search['director']
genre=search['main genre']
production=search['production_countries']
language=search['original_language']

# %%
#recommendation with popularity
df=movies

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew', 'director', 'main actor',
#        'main genre'],
#       dtype='object')

# %%
v=df['vote_count']
R=df['vote_average']
C=df['vote_average'].mean()
m=df['vote_count'].quantile(.70)

# %%
df['vote_average'].mean()
# Out:
# 6.092514036182159

# %%
df['weighted_average']=((R*v)+ (C*m))/(v+m)

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...           English
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...           English
# ...

# %%
movie_sorted_ranking=df.sort_values('weighted_average',ascending=False)

# %%
movie_sorted_ranking.head()
# Out:
#          budget                                             genres  \
# 1887   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3342    6000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 3237    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
#
#                                           homepage   id  \
# 1887                                           NaN  278
# 3342                  http://www.thegodfather.com/  238
# 662     http://www.foxmovies.com/movies/fight-club  550
# 3237                                           NaN  680
# 65    http://thedarkknight.warnerbros.com/dvdsite/  155
#
#                                                keywords original_language  \
# 1887  [{"id": 378, "name": "prison"}, {"id": 417, "n...           English
# ...

# %%
weight_average=movie_sorted_ranking.sort_values('weighted_average',ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
axis1=sns.barplot(x=weight_average['weighted_average'].head(10), y=weight_average['title'].head(10), data=weight_average)
plt.xlim(4, 10)
plt.title('Best Movies by average votes', weight='bold')
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_movies.png')

# %%
popularity=movie_sorted_ranking.sort_values('popularity',ascending=False)
plt.figure(figsize=(12,6))
ax=sns.barplot(x=popularity['popularity'].head(10), y=popularity['title'].head(10), data=popularity)

plt.title('Most Popular by Votes', weight='bold')
plt.xlabel('Score of Popularity', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_popular_movies.png')

# %%
popularity.head()
# Out:
#         budget                                             genres  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                      homepage      id  \
# 546              http://www.minionsmovie.com/  211672
# 95          http://www.interstellarmovie.net/  157336
# 788  http://www.foxmovies.com/movies/deadpool  293660
# 94                http://marvel.com/guardians  118340
# 127               http://www.madmaxmovie.com/   76341
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...           English
# 95   [{"id": 83, "name": "saving the world"}, {"id"...           English
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()
movie_scaled_df=scaling.fit_transform(df[['weighted_average','popularity']])
movie_normalized_df=pd.DataFrame(df,columns=['weighted_average','popularity'])
movie_normalized_df.head()
# Out:
#    weighted_average  popularity
# 0          7.148029  150.437577
# 1          6.807666  139.082615
# 2          6.276115  107.376788
# 3          7.509585  112.312950
# 4          6.098392   43.926995

# %%
df[['normalized_weight_average','normalized_popularity']]= movie_normalized_df

# %%
df['score'] = df['normalized_weight_average'] * 0.5 + df['normalized_popularity'] * 0.5
movies_scored_df = df.sort_values(['score'], ascending=False)
movies_scored_df[['title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                                   title  \
# 546                                             Minions
# 95                                         Interstellar
# 788                                            Deadpool
# 94                              Guardians of the Galaxy
# 127                                  Mad Max: Fury Road
# 28                                       Jurassic World
# 199   Pirates of the Caribbean: The Curse of the Bla...
# 82                       Dawn of the Planet of the Apes
# 200               The Hunger Games: Mockingjay - Part 1
# 88                                           Big Hero 6
# 108                                  Terminator Genisys
# 26                           Captain America: Civil War
# 3872                                           Whiplash
# 65                                      The Dark Knight
# 96                                            Inception
# 270                                         The Martian
# ...

# %%
scored_df = df.sort_values('score', ascending=False)

plt.figure(figsize=(16,6))

ax = sns.barplot(x=scored_df['score'].head(10), y=scored_df['title'].head(10), data=scored_df, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
# Out:
# Text(0, 0.5, 'Movie Title')

# %% [markdown]
# CONTENT BASED FILTERING

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...           English
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...           English
# ...

# %%
movies.drop(["weighted_average",'normalized_weight_average','normalized_popularity','score'],axis=1,inplace=True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...           English
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...           English
# ...

# %%
pip install ast
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies.dropna().isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# movie_id                0
# cast                    0
# crew                    0
# director                0
# main actor              0
# main genre              0
# dtype: int64

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...           English
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...           English
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...           English
# 1  [ocean, drug abuse, exotic island, east india ...           English
# ...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...           English
# 1  [ocean, drug abuse, exotic island, east india ...           English
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:6])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.head(3)
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...           English
# 1  [ocean, drug abuse, exotic island, east india ...           English
# 2  [spy, based on novel, secret agent, sequel, mi...           English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head(3)
# Out:
#       budget                                        genres  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]
# 1  300000000                  [Adventure, Fantasy, Action]
# 2  245000000                    [Action, Adventure, Crime]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...           English
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...           English
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...           English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
movies['overview']
# Out:
# 0       In the 22nd century, a paraplegic Marine is di...
# 1       Captain Barbossa, long believed to be dead, ha...
# 2       A cryptic message from Bond’s past sends him o...
# 3       Following the death of District Attorney Harve...
# 4       John Carter is a war-weary, former military ca...
#                               ...
# 4804    El Mariachi just wants to play his guitar and ...
# 4805    A newlywed couple's honeymoon is upended by th...
# 4806    "Signed, Sealed, Delivered" introduces a dedic...
# 4807    When ambitious New York attorney Sam is sent t...
# 4808    Ever since the second grade when he first saw ...
# Name: overview, Length: 4809, dtype: object

# %%
movies['overview'] = movies['overview'].fillna('').apply(lambda x: x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies['tags'][0]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d',
#  'SamWorthington',
#  'ZoeSaldana',
#  'SigourneyWeaver',
#  'StephenLang',
#  'MichelleRodriguez',
#  'GiovanniRibisi',
#  'JamesCameron']

# %%
movies['tags'] = movies['tags'].apply(lambda x: " ".join(x))

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=5000, stop_words='english')

# %%
vector = cv.fit_transform(movies['tags']).toarray()

# %%
vector.shape
# Out:
# (4809, 5000)

# %%
movies.drop('homepage',axis=1,inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
df = pd.DataFrame(columns=['budget', 'genres', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count', 'movie_id', 'cast', 'crew', 'director', 'main actor', 'main genre', 'tags'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [budget, genres, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, movie_id, cast, crew, director, main actor, main genre, tags]
# Index: []
#
# [0 rows x 26 columns]

# %%
def recommend(movie):
    index = movies[movies['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    recommended_movies = []
    for i in distances[1:11]:
        recommended_movies.append(movies.iloc[i[0]])
    return recommended_movies

# %%
recommended_movies = recommend('Titan A.E.')

# %%
for movie in recommended_movies:
    df = df.append(movie)
# Out:
# <ipython-input-86-b2e805e0e3f4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(movie)
# <ipython-input-86-b2e805e0e3f4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(movie)
# <ipython-input-86-b2e805e0e3f4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(movie)
# <ipython-input-86-b2e805e0e3f4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(movie)
# <ipython-input-86-b2e805e0e3f4>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(movie)
# ...

# %%
df
# Out:
#          budget                                             genres      id  \
# 459    80000000    [Western, Animation, Adventure, Comedy, Family]    9023
# 1201   40000000  [Animation, Comedy, Adventure, Family, Science...   68179
# 184   135000000  [Fantasy, Comedy, Animation, ScienceFiction, F...  228161
# 4049    2500000                [Action, Adventure, ScienceFiction]  146631
# 1329   38000000                        [Adventure, ScienceFiction]  299687
# 972    44000000  [Action, Adventure, Romance, ScienceFiction, T...   72710
# 61    176000003       [ScienceFiction, Fantasy, Action, Adventure]   76757
# 67    175000000     [Animation, Family, Adventure, ScienceFiction]   15512
# 973    44000000  [Action, Adventure, Romance, ScienceFiction, T...   72710
# 2972   10500000       [ScienceFiction, Adventure, Family, Fantasy]     601
#
#                                                keywords original_language  \
# ...

# %%
#pickle file downloading
# data={'model':search,'age':search['age'],'heart_disease':df['heart_disease'],'bmi':df['bmi'],'smoking_status':smoke}
